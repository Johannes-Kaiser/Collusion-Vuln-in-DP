# %%
import numpy as np
def open_noise_and_clipping(portion):
    # Load the .npy file
    pg_noise_multiplier_list = np.load(f'/vol/miltank/users/kaiserj/Clipping_vs_Sampling/exp_mia_3/mnist_4_[160_500]_[{portion}]/0/results/pg_noise_multiplier_list.npy')
    pg_noise_multiplier_list = pg_noise_multiplier_list[0]
    pg_sampling_rate = np.load(f'/vol/miltank/users/kaiserj/Clipping_vs_Sampling/exp_mia_3/mnist_4_[160_500]_[{portion}]/0/results/pg_sample_rates_list.npy')
    pg_sampling_rate = pg_sampling_rate[0]
    step_count = np.load(f'/vol/miltank/users/kaiserj/Clipping_vs_Sampling/exp_mia_3/mnist_4_[160_500]_[{portion}]/0/results/num_steps_list.npy')
    step_count = step_count[0]
    # Print the contents
    print(f"Portion: {portion}")
    print(f"noise_multiplier {pg_noise_multiplier_list}")
    print(f"sampling rate    {pg_sampling_rate}")
    print(f"step count       {step_count}")
    print()

print("Epsilon 16 vs 50 calibrated at delta 1e-10\n")
portions = [
    "02_08",
    "04_06",
    "06_04",
    "08_02",
]
for portion in portions:
    open_noise_and_clipping(portion)
# Out:
# Epsilon 16 vs 50 calibrated at delta 1e-10
#
# Portion: 02_08
# noise_multiplier [0.55200461 0.55200461]
# sampling rate    [0.01368713 0.07458496]
# step count       [0.01368713 0.07458496]
#
# Portion: 04_06
# noise_multiplier [0.59300421 0.59300421]
# sampling rate    [0.01913452 0.09136963]
# step count       [0.01913452 0.09136963]
#
# Portion: 06_04
# noise_multiplier [0.64850367 0.64850367]
# sampling rate    [0.02758789 0.11517334]
# step count       [0.02758789 0.11517334]
#
# Portion: 08_02
# noise_multiplier [0.7275029 0.7275029]
# sampling rate    [0.04074097 0.14978027]
# step count       [0.04074097 0.14978027]
